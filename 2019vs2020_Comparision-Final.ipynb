# %%
#Import Depencies
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#File of Comtrade
file = 'TMEC trade Ag.csv'
trade_data = pd.read_csv(file)
trade_df=pd.DataFrame(trade_data)
trade_df.replace(',','', regex=True, inplace=True)
trade_df.columns
# Out:
# Index(['Indicator', 'Trade flow', 'Commodity', 'Partner', 'Reporter',
#        '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#        '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
#        '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#        '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#        '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12',
#        'Unnamed: 65', 'Unnamed: 66'],
#       dtype='object')

# %%
#Getting the totals for 2019 and 2020
Columns = ['2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
       '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
       '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
       '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
       '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
       '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
       '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
       '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
       '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
       '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']
trade_df[Columns] = trade_df[Columns].apply(pd.to_numeric, errors = 'coerce')
trade_df['Total 2019'] = trade_df.fillna(0)['2019-01'] + trade_df.fillna(0)['2019-02']+ trade_df.fillna(0)['2019-03']+ trade_df.fillna(0)['2019-04']\
                        + trade_df.fillna(0)['2019-05'] + trade_df.fillna(0)['2019-06']+ trade_df.fillna(0)['2019-07']+ trade_df.fillna(0)['2019-08']\
                        + trade_df.fillna(0)['2019-09']+ trade_df.fillna(0)['2019-10']+ trade_df.fillna(0)['2019-11']+ trade_df.fillna(0)['2019-12']
trade_df['Total 2020'] = trade_df.fillna(0)['2020-01'] + trade_df.fillna(0)['2020-02']+ trade_df.fillna(0)['2020-03']+ trade_df.fillna(0)['2020-04']\
                        + trade_df.fillna(0)['2020-05'] + trade_df.fillna(0)['2020-06']+ trade_df.fillna(0)['2020-07']+ trade_df.fillna(0)['2020-08']\
                        + trade_df.fillna(0)['2020-09']+ trade_df.fillna(0)['2020-10']+ trade_df.fillna(0)['2020-11']


trade_df
# Out:
#       Indicator Trade flow                          Commodity Partner  \
# 0   Value (US$)    Imports  TOTAL Total of all HS commodities  Canada
# 1   Value (US$)    Imports  TOTAL Total of all HS commodities  Canada
# 2   Value (US$)    Imports  TOTAL Total of all HS commodities  Canada
# 3   Value (US$)    Imports  TOTAL Total of all HS commodities  Mexico
# 4   Value (US$)    Imports  TOTAL Total of all HS commodities  Mexico
# ..          ...        ...                                ...     ...
# 90  Value (US$)    Exports   22 Beverages spirits and vinegar     USA
# 91  Value (US$)    Exports   22 Beverages spirits and vinegar     USA
# 92  Value (US$)    Exports   22 Beverages spirits and vinegar   World
# 93  Value (US$)    Exports   22 Beverages spirits and vinegar   World
# 94  Value (US$)    Exports   22 Beverages spirits and vinegar   World
#
#    Reporter       2016-01       2016-02       2016-03       2016-04  \
# ...

# %%
#Extract just the inforation for totals analysis
clean_trade_df = trade_df[['Trade flow', 'Commodity', 'Partner', 'Reporter','Total 2019','Total 2020']]
clean_trade_df
# Out:
#    Trade flow                          Commodity Partner Reporter  \
# 0     Imports  TOTAL Total of all HS commodities  Canada   Canada
# 1     Imports  TOTAL Total of all HS commodities  Canada   Mexico
# 2     Imports  TOTAL Total of all HS commodities  Canada      USA
# 3     Imports  TOTAL Total of all HS commodities  Mexico   Canada
# 4     Imports  TOTAL Total of all HS commodities  Mexico      USA
# ..        ...                                ...     ...      ...
# 90    Exports   22 Beverages spirits and vinegar     USA   Canada
# 91    Exports   22 Beverages spirits and vinegar     USA   Mexico
# 92    Exports   22 Beverages spirits and vinegar   World   Canada
# 93    Exports   22 Beverages spirits and vinegar   World   Mexico
# 94    Exports   22 Beverages spirits and vinegar   World      USA
#
#       Total 2019    Total 2020
# 0   3.109817e+09  1.912664e+08
# 1   9.804227e+09  6.687902e+09
# 2   3.266286e+11  2.509091e+11
# 3   2.784201e+10  1.994026e+10
# ...

# %%
all_hs_df = clean_trade_df.loc[(clean_trade_df['Commodity'] == 'TOTAL Total of all HS commodities'),:]
world_df = all_hs_df.loc[(clean_trade_df['Partner'] == 'World'),:]
world_df_imports = world_df.loc[(world_df['Trade flow'] == 'Imports'),:]
world_df_exports= world_df.loc[(world_df['Trade flow'] == 'Exports'),:]

# %%
#Extract the data for month vs month analysis of 2019 and 2020.
trade_df_2 = trade_df[['Trade flow', 'Commodity', 'Partner', 'Reporter',
       '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
       '2019-07', '2019-08', '2019-09', '2019-10','2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
       '2020-07', '2020-08', '2020-09', '2020-10']]
trade_df_Comtotal = trade_df_2.loc[(trade_df_2['Partner'] == 'World') & (trade_df_2['Commodity'] == 'TOTAL Total of all HS commodities') ,:]
trade_df_Comtotal
# Out:
#    Trade flow                          Commodity Partner Reporter  \
# 7     Imports  TOTAL Total of all HS commodities   World   Canada
# 8     Imports  TOTAL Total of all HS commodities   World   Mexico
# 9     Imports  TOTAL Total of all HS commodities   World      USA
# 16    Exports  TOTAL Total of all HS commodities   World   Canada
# 17    Exports  TOTAL Total of all HS commodities   World   Mexico
# 18    Exports  TOTAL Total of all HS commodities   World      USA
#
#          2019-01       2019-02       2019-03       2019-04       2019-05  \
# 7   3.607938e+10  3.507667e+10  4.007801e+10  3.884289e+10  4.026278e+10
# 8   3.726301e+10  3.507409e+10  3.753122e+10  3.807688e+10  4.079474e+10
# 9   2.107566e+11  1.912136e+11  2.135730e+11  2.147359e+11  2.268724e+11
# 16  3.421806e+10  3.240187e+10  3.880391e+10  3.719271e+10  4.119054e+10
# 17  3.261969e+10  3.640921e+10  3.901603e+10  3.944706e+10  4.182264e+10
# ...

# %%
#Getting the data just for USA
trade_df_Comtotal_EU = trade_df_Comtotal.loc[(trade_df_Comtotal['Reporter']=='USA'),:]
trade_df_Comtotal_EU = trade_df_Comtotal_EU[['Trade flow','2019-01','2020-01','2019-02','2020-02', '2019-03','2020-03', 
                                             '2019-04', '2020-04','2019-05', '2020-05','2019-06','2020-06','2019-07','2020-07',
                                             '2019-08','2020-08','2019-09','2020-09','2019-10','2020-10'
                                             ]].set_index('Trade flow').T.rename_axis('Date').reset_index()

trade_df_Comtotal_EU["Imports"] = trade_df_Comtotal_EU["Imports"].astype(float)
trade_df_Comtotal_EU["Exports"] = trade_df_Comtotal_EU["Exports"].astype(float)

# %%
#Plotting the data
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(15,10))

sns.set_color_codes("pastel")
sns.barplot(x='Date', y='Imports', data=trade_df_Comtotal_EU,
            label="Imports", color="b")
sns.set_color_codes("bright")
sns.barplot(x="Date", y='Exports', data=trade_df_Comtotal_EU,
             label="Exports", color="b")
ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set( ylabel="",
       title="USA´s imports and exports 2019 vs 2020")
sns.despine(left=True, bottom=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.annotate('Start of Covid', xy=(5, 2.107566e+11), xytext=(4.5, 2.307566e+11),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('Pick of Covid Recovered', xy=(19, 2.107566e+11), xytext=(15, 2.000000e+11),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(15, 200000000000.0, 'Pick of Covid Recovered')

# %%
#Getting the data and plotting just for Mexico

trade_df_Comtotal_MX = trade_df_Comtotal.loc[(trade_df_Comtotal['Reporter']=='Mexico'),:]
trade_df_Comtotal_MX = trade_df_Comtotal_MX[['Trade flow','2019-01','2020-01','2019-02','2020-02', '2019-03','2020-03', 
                                             '2019-04', '2020-04','2019-05', '2020-05','2019-06','2020-06','2019-07','2020-07',
                                             '2019-08','2020-08','2019-09','2020-09','2019-10','2020-10'
                                             ]].set_index('Trade flow').T.rename_axis('Date').reset_index()

trade_df_Comtotal_MX["Imports"] = trade_df_Comtotal_MX["Imports"].astype(float)
trade_df_Comtotal_MX["Exports"] = trade_df_Comtotal_MX["Exports"].astype(float)

sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(15,10))

sns.set_color_codes("pastel")
sns.barplot(x='Date', y='Imports', data=trade_df_Comtotal_MX,
            label="Imports", color="g")
sns.set_color_codes("bright")
sns.barplot(x="Date", y='Exports', data=trade_df_Comtotal_MX,
            label="Exports", color="g")
ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set( ylabel="",
       title="Mexico´s imports and exports 2019 vs 2020")
sns.despine(left=True, bottom=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.annotate('Start of Covid', xy=(5, 3.9e10), xytext=(5, 4.5e10),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('Pick of Covid Recovered', xy=(19, 3.5e10), xytext=(17, 4.5e10),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(17, 45000000000.0, 'Pick of Covid Recovered')

# %%
#Getting the data and plotting just for Canada

trade_df_Comtotal_C = trade_df_Comtotal.loc[(trade_df_Comtotal['Reporter']=='Canada'),:]
trade_df_Comtotal_C = trade_df_Comtotal_C[['Trade flow','2019-01','2020-01','2019-02','2020-02', '2019-03','2020-03', 
                                             '2019-04', '2020-04','2019-05', '2020-05','2019-06','2020-06','2019-07','2020-07',
                                             '2019-08','2020-08','2019-09','2020-09','2019-10','2020-10'
                                             ]].set_index('Trade flow').T.rename_axis('Date').reset_index()

trade_df_Comtotal_C["Imports"] = trade_df_Comtotal_C["Imports"].astype(float)
trade_df_Comtotal_C["Exports"] = trade_df_Comtotal_C["Exports"].astype(float)

sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(15,10))

sns.set_color_codes("pastel")
sns.barplot(x='Date', y='Imports', data=trade_df_Comtotal_C,
            label="Imports", color="r")
sns.set_color_codes("bright")
sns.barplot(x="Date", y='Exports', data=trade_df_Comtotal_C,
            label="Exports", color="r")
ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set( ylabel="",
       title="Canada´s imports and exports 2019 vs 2020")
sns.despine(left=True, bottom=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.annotate('Start of Covid', xy=(5, 3.9e10), xytext=(5, 4.5e10),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('Pick of Covid Recovered', xy=(19, 3.5e10), xytext=(17, 4.5e10),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(17, 45000000000.0, 'Pick of Covid Recovered')

# %%
#Porcentual Change
#Getting the data for Exports
trade_df_Comtotal_P = trade_df_Comtotal.loc[(trade_df_Comtotal['Trade flow']=='Exports'),:]

trade_df_Comtotal_P = trade_df_Comtotal_P[['Reporter','2019-01','2020-01','2019-02','2020-02', '2019-03','2020-03', 
                                             '2019-04', '2020-04','2019-05', '2020-05','2019-06','2020-06','2019-07','2020-07',
                                             '2019-08','2020-08','2019-09','2020-09','2019-10','2020-10'
                                             ]].set_index('Reporter').T.rename_axis('Date').reset_index()

trade_df_Comtotal_P["Total Exports"] = trade_df_Comtotal_P.iloc[:, -4:-1].sum(axis=1)
trade_df_Comtotal_P["Total Exports"] = trade_df_Comtotal_P.sum(axis=1)

trade_df_Comtotal_P['Exports Porcentual Change'] = trade_df_Comtotal_P["Total Exports"].pct_change()


#Plotting the data
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(15,10))

sns.set_color_codes("pastel")
sns.barplot(x="Date", y='Total Exports', data=trade_df_Comtotal_P,
              label="Exports", color="c")
ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set(title="Porcentual Change in Exports for 2019 vs 2020 of TMEC")
sns.despine(left=True, bottom=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.annotate('Start of Covid', xy=(5, 2.107566e+11), xytext=(4.5, 2.307566e+11),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('Pick of Covid Recovered', xy=(19, 2.107566e+11), xytext=(15, 2.000000e+11),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax2 = ax.twinx()
sns.lineplot(data = trade_df_Comtotal_P['Exports Porcentual Change'], marker='o', sort = False, ax=ax2)
ax2.grid(False)
